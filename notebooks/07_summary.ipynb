# %% [markdown]
# # Model Performance Summary
#
# ## Objective
# This notebook consolidates and compares the performance of all models developed in this project, including linear models, tree-based models, and LSTM-based deep learning models.
#
# The goal is to evaluate both **predictive accuracy** and **trading performance**, highlighting the difference between statistical fit and tradability.

# %%
import pandas as pd

# %% [markdown]
# ## Model Comparison Table

# %%
summary_df = pd.DataFrame({
    "Model": [
        "Ridge Regression",
        "Random Forest",
        "LSTM"
    ],
    "Target": [
        "Returns",
        "Returns",
        "Price"
    ],
    "Test RMSE / MSE": [
        0.00821,     
        355.5143,    
        0.000061     
    ],
    "Buy & Hold %": [
        38.4,        
        38.4,
        33.5
    ],
    "Strategy %": [
        0.44,         
        196.16,       
        34          
    ]
})

summary_df
# Out:
#               Model   Target  Test RMSE / MSE  Buy & Hold %  Strategy %
# 0  Ridge Regression  Returns         0.008210          38.4        0.44
# 1     Random Forest  Returns       355.514300          38.4      196.16
# 2              LSTM    Price         0.000061          33.5       34.00

# %% [markdown]
# ### Observations
# - Tree-based models (Random Forest) produced the most consistent and tradable signals.
# - The LSTM achieved the lowest prediction error but failed to generate trades under a conservative confidence threshold.
# - This highlights the key distinction between **prediction accuracy** and **trading profitability** in financial time series.

# %% [markdown]
# ### Key Takeaways
# - Feature engineering and model choice significantly impact trading performance.
# - Lower prediction error does not necessarily translate into profitable strategies.
# - Conservative signal thresholds reduce overtrading but may eliminate trading activity entirely.
